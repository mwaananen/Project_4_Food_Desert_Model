# %%
#bring in libraries
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data_df = pd.read_excel('FoodAccessResearchAtlasData2019.xlsx')
data_df.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0  0.000000                  0  ...
# 1                  0     181.0  8.341014                  1  ...
# 2                  0       0.0  0.000000                  0  ...
# 3                  0       0.0  0.000000                  0  ...
# 4                  0     181.0  1.681219                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %%
mn_df = data_df[data_df['State'] == 'Minnesota']
mn_df
# Out:
#        CensusTract      State                  County  Urban  Pop2010  \
# 35210  27001790502  Minnesota           Aitkin County      0     3262
# 35211  27001770200  Minnesota           Aitkin County      0     2336
# 35212  27001790501  Minnesota           Aitkin County      0     1957
# 35213  27001770100  Minnesota           Aitkin County      0     2327
# 35214  27001770400  Minnesota           Aitkin County      0     3052
# ...            ...        ...                     ...    ...      ...
# 36539  27171100702  Minnesota           Wright County      1     8207
# 36540  27173970300  Minnesota  Yellow Medicine County      0     2517
# 36541  27173970200  Minnesota  Yellow Medicine County      0     2520
# 36542  27173970400  Minnesota  Yellow Medicine County      0     2030
# 36543  27173970100  Minnesota  Yellow Medicine County      0     3371
#
#        OHU2010  GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 35210     1494                  0       7.0  0.214592                  0  ...
# 35211      995                  0      11.0  0.470890                  1  ...
# 35212      916                  0      11.0  0.562085                  1  ...
# 35213     1080                  0       5.0  0.214869                  1  ...
# 35214     1424                  0       0.0  0.000000                  1  ...
# ...        ...                ...       ...       ...                ...  ...
# 36539     2916                  0      48.0  0.584867                  0  ...
# 36540     1044                  0      49.0  1.946762                  0  ...
# 36541     1075                  0     122.0  4.841270                  0  ...
# 36542      794                  0       1.0  0.049261                  1  ...
# 36543     1379                  0     118.0  3.500445                  0  ...
#
#        TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# 35210        1032.0      3188.0        10.0         8.0         1.0
# 35211         467.0      2231.0        18.0         2.0         0.0
# 35212         613.0      1913.0         4.0         1.0         1.0
# 35213         668.0      2255.0         3.0         4.0         1.0
# 35214         803.0      2758.0         3.0         5.0         0.0
# ...             ...         ...         ...         ...         ...
# 36539         557.0      7703.0        71.0        91.0         3.0
# 36540         467.0      2452.0         2.0         5.0         0.0
# 36541         641.0      2479.0         6.0         7.0         0.0
# 36542         297.0      1920.0         1.0         6.0         5.0
# 36543         626.0      2955.0         7.0        15.0         1.0
#
#        TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 35210       19.0          36.0           13.0       52.0       83.0
# 35211       37.0          48.0           26.0       33.0      184.0
# 35212       19.0          19.0           14.0       38.0       58.0
# 35213       45.0          19.0           16.0       44.0       62.0
# 35214      233.0          53.0           36.0       88.0      184.0
# ...          ...           ...            ...        ...        ...
# 36539       47.0         292.0          299.0      150.0      286.0
# 36540       11.0          47.0           64.0       30.0       67.0
# 36541        1.0          27.0           44.0       63.0      105.0
# 36542       31.0          67.0          170.0       30.0       58.0
# 36543      271.0         122.0          119.0       87.0      136.0
#
# [1334 rows x 147 columns]

# %% [markdown]
# ### The first time this was ran through, the Accuracy of the model came back around 30%! The first check to see about where some data challenges may have existed was running the .isnull() below. Eight (8) fields were found to be "NaN". All were in the column "MedianFamilyIncome". Instead of removing the rows with "NaN", opted to instead fill in those fields with the "median family income" for the county they were in.
#
# ### After completing this, lesson learned: having null/NaN values in the dataset, even if not too many, can really mess with your models . . . the first iteration later resulted in an Accuracy around 76% after just this first change.
#
# ### Also, when trying to figure out why the 30% Accuracy from earlier, below had looked at the .value_counts() of our target column "LAhalfand10". There were more "yes" (1) values for our chosen target than "no" (0) resulting in unbalanced data . . . if anything, ideally data should skew towards more "no" (0), but this did not seem to affect the results in a negative way.

# %%
grouped_df.isnull().sum()
# Out:
# County                0
# Urban                 0
# Pop2010               0
# OHU2010               0
# GroupQuartersFlag     0
# NUMGQTRS              0
# PCTGQTRS              0
# HUNVFlag              0
# LowIncomeTracts       0
# PovertyRate           0
# MedianFamilyIncome    8
# TractLOWI             0
# TractKids             0
# TractSeniors          0
# TractWhite            0
# TractBlack            0
# TractAsian            0
# TractNHOPI            0
# TractAIAN             0
# TractOMultir          0
# TractHispanic         0
# TractHUNV             0
# TractSNAP             0
# LAhalfand10           0
# dtype: int64

# %%
grouped_df = mn_df[["County", "Urban", "Pop2010", "OHU2010",
                            "GroupQuartersFlag", "NUMGQTRS", "PCTGQTRS", "HUNVFlag", "LowIncomeTracts", 
                            "PovertyRate", "MedianFamilyIncome", "TractLOWI", "TractKids", "TractSeniors", 
                            "TractWhite", "TractBlack", "TractAsian", "TractNHOPI", "TractAIAN", 
                            "TractOMultir", "TractHispanic", "TractHUNV", "TractSNAP", "LAhalfand10"]]
grouped_df.head()
# Out:
#               County  Urban  Pop2010  OHU2010  GroupQuartersFlag  NUMGQTRS  \
# 35210  Aitkin County      0     3262     1494                  0       7.0
# 35211  Aitkin County      0     2336      995                  0      11.0
# 35212  Aitkin County      0     1957      916                  0      11.0
# 35213  Aitkin County      0     2327     1080                  0       5.0
# 35214  Aitkin County      0     3052     1424                  0       0.0
#
#        PCTGQTRS  HUNVFlag  LowIncomeTracts  PovertyRate  ...  TractWhite  \
# 35210  0.214592         0                1     7.623169  ...      3188.0
# 35211  0.470890         0                1    11.283691  ...      2231.0
# 35212  0.562085         0                1    11.358811  ...      1913.0
# 35213  0.214869         0                1    12.527473  ...      2255.0
# 35214  0.000000         0                1    15.459098  ...      2758.0
#
#        TractBlack  TractAsian  TractNHOPI  TractAIAN  TractOMultir  \
# 35210        10.0         8.0         1.0       19.0          36.0
# 35211        18.0         2.0         0.0       37.0          48.0
# 35212         4.0         1.0         1.0       19.0          19.0
# 35213         3.0         4.0         1.0       45.0          19.0
# 35214         3.0         5.0         0.0      233.0          53.0
#
#        TractHispanic  TractHUNV  TractSNAP  LAhalfand10
# 35210           13.0       52.0       83.0            0
# 35211           26.0       33.0      184.0            1
# 35212           14.0       38.0       58.0            1
# 35213           16.0       44.0       62.0            1
# 35214           36.0       88.0      184.0            1
#
# [5 rows x 24 columns]

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 35210 to 36543
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   County              1334 non-null   object
#  1   Urban               1334 non-null   int64
#  2   Pop2010             1334 non-null   int64
#  3   OHU2010             1334 non-null   int64
#  4   GroupQuartersFlag   1334 non-null   int64
#  5   NUMGQTRS            1334 non-null   float64
#  6   PCTGQTRS            1334 non-null   float64
#  7   HUNVFlag            1334 non-null   int64
#  8   LowIncomeTracts     1334 non-null   int64
#  9   PovertyRate         1334 non-null   float64
#  10  MedianFamilyIncome  1326 non-null   float64
#  11  TractLOWI           1334 non-null   float64
#  12  TractKids           1334 non-null   float64
#  13  TractSeniors        1334 non-null   float64
#  14  TractWhite          1334 non-null   float64
#  15  TractBlack          1334 non-null   float64
#  16  TractAsian          1334 non-null   float64
#  17  TractNHOPI          1334 non-null   float64
#  18  TractAIAN           1334 non-null   float64
#  19  TractOMultir        1334 non-null   float64
#  20  TractHispanic       1334 non-null   float64
#  21  TractHUNV           1334 non-null   float64
#  22  TractSNAP           1334 non-null   float64
#  23  LAhalfand10         1334 non-null   int64
# dtypes: float64(16), int64(7), object(1)
# memory usage: 260.5+ KB

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()), ["County", "MedianFamilyIncome"]]
# Out:
#                   County  MedianFamilyIncome
# 35842    Hennepin County                 NaN
# 35867    Hennepin County                 NaN
# 35880    Hennepin County                 NaN
# 35883    Hennepin County                 NaN
# 35884    Hennepin County                 NaN
# 36117      Ramsey County                 NaN
# 36458  Washington County                 NaN
# 36459  Washington County                 NaN

# %%
median = grouped_df.loc[grouped_df["County"] == "Hennepin County"]["MedianFamilyIncome"].median()
median
# Out:
# 95140.5

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) & (grouped_df["County"] == "Hennepin County"), "MedianFamilyIncome"] = median

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) | (grouped_df["County"] == "Hennepin County"), ["County", "MedianFamilyIncome"]]
# Out:
#                   County  MedianFamilyIncome
# 35586    Hennepin County            157891.0
# 35587    Hennepin County            165500.0
# 35588    Hennepin County            135417.0
# 35589    Hennepin County            196845.0
# 35590    Hennepin County             94792.0
# ...                  ...                 ...
# 35883    Hennepin County             95140.5
# 35884    Hennepin County             95140.5
# 36117      Ramsey County                 NaN
# 36458  Washington County                 NaN
# 36459  Washington County                 NaN
#
# [302 rows x 2 columns]

# %%
median2 = grouped_df.loc[grouped_df["County"] == "Washington County"]["MedianFamilyIncome"].median()
median2
# Out:
# 106858.0

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) & (grouped_df["County"] == "Washington County"), "MedianFamilyIncome"] = median2

# %%
median3 = grouped_df.loc[grouped_df["County"] == "Ramsey County"]["MedianFamilyIncome"].median()
median3
# Out:
# 76914.0

# %%
grouped_df.loc[(grouped_df["MedianFamilyIncome"].isnull()) & (grouped_df["County"] == "Ramsey County"), "MedianFamilyIncome"] = median3

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 35210 to 36543
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   County              1334 non-null   object
#  1   Urban               1334 non-null   int64
#  2   Pop2010             1334 non-null   int64
#  3   OHU2010             1334 non-null   int64
#  4   GroupQuartersFlag   1334 non-null   int64
#  5   NUMGQTRS            1334 non-null   float64
#  6   PCTGQTRS            1334 non-null   float64
#  7   HUNVFlag            1334 non-null   int64
#  8   LowIncomeTracts     1334 non-null   int64
#  9   PovertyRate         1334 non-null   float64
#  10  MedianFamilyIncome  1334 non-null   float64
#  11  TractLOWI           1334 non-null   float64
#  12  TractKids           1334 non-null   float64
#  13  TractSeniors        1334 non-null   float64
#  14  TractWhite          1334 non-null   float64
#  15  TractBlack          1334 non-null   float64
#  16  TractAsian          1334 non-null   float64
#  17  TractNHOPI          1334 non-null   float64
#  18  TractAIAN           1334 non-null   float64
#  19  TractOMultir        1334 non-null   float64
#  20  TractHispanic       1334 non-null   float64
#  21  TractHUNV           1334 non-null   float64
#  22  TractSNAP           1334 non-null   float64
#  23  LAhalfand10         1334 non-null   int64
# dtypes: float64(16), int64(7), object(1)
# memory usage: 260.5+ KB

# %%
print(grouped_df.dtypes)
# Out:
# County                 object
# Urban                   int64
# Pop2010                 int64
# OHU2010                 int64
# GroupQuartersFlag       int64
# NUMGQTRS              float64
# PCTGQTRS              float64
# HUNVFlag                int64
# LowIncomeTracts         int64
# PovertyRate           float64
# MedianFamilyIncome    float64
# TractLOWI             float64
# TractKids             float64
# TractSeniors          float64
# TractWhite            float64
# TractBlack            float64
# TractAsian            float64
# TractNHOPI            float64
# TractAIAN             float64
# TractOMultir          float64
# TractHispanic         float64
# TractHUNV             float64
# TractSNAP             float64
# LAhalfand10             int64
# dtype: object

# %%
grouped_df.nunique()
# Out:
# County                  87
# Urban                    2
# Pop2010               1190
# OHU2010                989
# GroupQuartersFlag        2
# NUMGQTRS               278
# PCTGQTRS              1088
# HUNVFlag                 2
# LowIncomeTracts          2
# PovertyRate           1328
# MedianFamilyIncome    1269
# TractLOWI              963
# TractKids              887
# TractSeniors           702
# TractWhite            1161
# TractBlack             503
# TractAsian             424
# TractNHOPI              20
# TractAIAN              167
# TractOMultir           429
# TractHispanic          446
# TractHUNV              336
# TractSNAP              378
# LAhalfand10              2
# dtype: int64

# %%
# Convert population counts to percentages for demographic observations
grouped_df["PctLOWI"] = grouped_df["TractLOWI"] / grouped_df["Pop2010"]
grouped_df["PctKids"] = grouped_df["TractKids"] / grouped_df["Pop2010"]
grouped_df["PctSeniors"] = grouped_df["TractSeniors"] / grouped_df["Pop2010"]
grouped_df["PctWhite"] = grouped_df["TractWhite"] / grouped_df["Pop2010"]
grouped_df["PctBlack"] = grouped_df["TractBlack"] / grouped_df["Pop2010"]
grouped_df["PctAsian"] = grouped_df["TractAsian"] / grouped_df["Pop2010"]
grouped_df["PctNHOPI"] = grouped_df["TractNHOPI"] / grouped_df["Pop2010"]
grouped_df["PctAIAN"] = grouped_df["TractAIAN"] / grouped_df["Pop2010"]
grouped_df["PctOMultir"] = grouped_df["TractOMultir"] / grouped_df["Pop2010"]
grouped_df["PctHispanic"] = grouped_df["TractHispanic"] / grouped_df["Pop2010"]
grouped_df["PctHUNV"] = grouped_df["TractHUNV"] / grouped_df["Pop2010"]
grouped_df["PctSNAP"] = grouped_df["TractSNAP"] / grouped_df["Pop2010"]
# Out:
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctLOWI"] = grouped_df["TractLOWI"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctKids"] = grouped_df["TractKids"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctSeniors"] = grouped_df["TractSeniors"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctWhite"] = grouped_df["TractWhite"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctBlack"] = grouped_df["TractBlack"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctAsian"] = grouped_df["TractAsian"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctNHOPI"] = grouped_df["TractNHOPI"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctAIAN"] = grouped_df["TractAIAN"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctOMultir"] = grouped_df["TractOMultir"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctHispanic"] = grouped_df["TractHispanic"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctHUNV"] = grouped_df["TractHUNV"] / grouped_df["Pop2010"]
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\1782347657.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df["PctSNAP"] = grouped_df["TractSNAP"] / grouped_df["Pop2010"]

# %%
# drop columns with population counts
grouped_df.drop(columns=['TractLOWI','TractKids','TractSeniors','TractWhite','TractBlack','TractAsian','TractNHOPI',
                         'TractAIAN','TractOMultir','TractHispanic','TractHUNV','TractSNAP'], inplace=True)
# Out:
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\464002592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df.drop(columns=['TractLOWI','TractKids','TractSeniors','TractWhite','TractBlack','TractAsian','TractNHOPI',

# %%
list(grouped_df.columns)
# Out:
# ['County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LAhalfand10',
#  'PctLOWI',
#  'PctKids',
#  'PctSeniors',
#  'PctWhite',
#  'PctBlack',
#  'PctAsian',
#  'PctNHOPI',
#  'PctAIAN',
#  'PctOMultir',
#  'PctHispanic',
#  'PctHUNV',
#  'PctSNAP']

# %%
# Convert categorical data to numeric with `pd.get_dummies`  ***

grouped_df.drop(columns=["County"], inplace=True)
dummies_df = pd.get_dummies(grouped_df) #did this when had categorical data
dummies_df
# Out:
# C:\Users\Micha\AppData\Local\Temp\ipykernel_25824\3822044187.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_df.drop(columns=["County"], inplace=True)
#        Urban  Pop2010  OHU2010  GroupQuartersFlag  NUMGQTRS  PCTGQTRS  \
# 35210      0     3262     1494                  0       7.0  0.214592
# 35211      0     2336      995                  0      11.0  0.470890
# 35212      0     1957      916                  0      11.0  0.562085
# 35213      0     2327     1080                  0       5.0  0.214869
# 35214      0     3052     1424                  0       0.0  0.000000
# ...      ...      ...      ...                ...       ...       ...
# 36539      1     8207     2916                  0      48.0  0.584867
# 36540      0     2517     1044                  0      49.0  1.946762
# 36541      0     2520     1075                  0     122.0  4.841270
# 36542      0     2030      794                  0       1.0  0.049261
# 36543      0     3371     1379                  0     118.0  3.500445
#
#        HUNVFlag  LowIncomeTracts  PovertyRate  MedianFamilyIncome  ...  \
# 35210         0                1     7.623169             63287.0  ...
# 35211         0                1    11.283691             63073.0  ...
# 35212         0                1    11.358811             54821.0  ...
# 35213         0                1    12.527473             57813.0  ...
# 35214         0                1    15.459098             53309.0  ...
# ...         ...              ...          ...                 ...  ...
# 36539         1                0    10.240964             80273.0  ...
# 36540         0                0     8.866583             72917.0  ...
# 36541         0                0    11.030741             70066.0  ...
# 36542         0                1    12.297893             64483.0  ...
# 36543         0                0    19.607843             70722.0  ...
#
#        PctSeniors  PctWhite  PctBlack  PctAsian  PctNHOPI   PctAIAN  \
# 35210    0.316370  0.977315  0.003066  0.002452  0.000307  0.005825
# 35211    0.199914  0.955051  0.007705  0.000856  0.000000  0.015839
# 35212    0.313235  0.977517  0.002044  0.000511  0.000511  0.009709
# 35213    0.287065  0.969059  0.001289  0.001719  0.000430  0.019338
# 35214    0.263106  0.903670  0.000983  0.001638  0.000000  0.076343
# ...           ...       ...       ...       ...       ...       ...
# 36539    0.067869  0.938589  0.008651  0.011088  0.000366  0.005727
# 36540    0.185538  0.974176  0.000795  0.001986  0.000000  0.004370
# 36541    0.254365  0.983730  0.002381  0.002778  0.000000  0.000397
# 36542    0.146305  0.945813  0.000493  0.002956  0.002463  0.015271
# 36543    0.185702  0.876594  0.002077  0.004450  0.000297  0.080392
#
#        PctOMultir  PctHispanic   PctHUNV   PctSNAP
# 35210    0.011036     0.003985  0.015941  0.025445
# 35211    0.020548     0.011130  0.014127  0.078767
# 35212    0.009709     0.007154  0.019417  0.029637
# 35213    0.008165     0.006876  0.018908  0.026644
# 35214    0.017366     0.011796  0.028834  0.060288
# ...           ...          ...       ...       ...
# 36539    0.035579     0.036432  0.018277  0.034848
# 36540    0.018673     0.025427  0.011919  0.026619
# 36541    0.010714     0.017460  0.025000  0.041667
# 36542    0.033005     0.083744  0.014778  0.028571
# 36543    0.036191     0.035301  0.025808  0.040344
#
# [1334 rows x 23 columns]

# %%
# Split our preprocessed data into our features and target arrays 
y = dummies_df.LAhalfand10.values
X = dummies_df.drop(columns="LAhalfand10").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances ****
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Regarding iterations: began by creating "First" and "Second" hidden layers with hidden_nodes_layer1 at 800 and ...layer2 at 500 and epochs below at 100. After running everything, "Accuracy" was around 75%-76%! When training the model, it did seem to be overfitting, so bumped the epochs down to 10. Also tried adding a "Third" hidden layer with 50 nodes, and "Accuracy" was still coming out at 76%-77%. After some "instructor intervention" to see if it would help/hurt, ended up with the two hidden layers below with less neurons than had intially been tried. We also removed the "County" column (above).
#
# ### We also decided to convert the demographic population numbers from "counts" to "percents" (above) since it seemed to better reflect the tract's portion in the total population of the county. Doing this got us our best results yet . . . 85% Accuracy below!

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])

hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               2300
#
#  dense_4 (Dense)             (None, 50)                5050
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 7401 (28.91 KB)
# Trainable params: 7401 (28.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
dummies_df["LAhalfand10"].value_counts()
# Out:
# 1    940
# 0    394
# Name: LAhalfand10, dtype: int64

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=10)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 2ms/step - loss: 0.6378 - accuracy: 0.6290
# Epoch 2/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.7920
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3826 - accuracy: 0.8300
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3401 - accuracy: 0.8350
# Epoch 5/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.8520
# Epoch 6/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2998 - accuracy: 0.8590
# Epoch 7/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2869 - accuracy: 0.8660
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2845 - accuracy: 0.8720
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.8650
# Epoch 10/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2645 - accuracy: 0.8670

# %%
type(fit_model)
# Out:
# keras.src.callbacks.History

# %%
fit_model.history
# Out:
# {'loss': [0.6377953886985779,
#   0.4652319848537445,
#   0.38260790705680847,
#   0.34008023142814636,
#   0.3164021074771881,
#   0.2997659742832184,
#   0.286857932806015,
#   0.2845284044742584,
#   0.27212539315223694,
#   0.2645370662212372],
#  'accuracy': [0.6290000081062317,
#   0.7919999957084656,
#   0.8299999833106995,
#   0.8349999785423279,
#   0.8519999980926514,
#   0.859000027179718,
#   0.8659999966621399,
#   0.871999979019165,
#   0.8650000095367432,
#   0.8669999837875366]}

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 11/11 - 0s - loss: 0.3538 - accuracy: 0.8503 - 119ms/epoch - 11ms/step
# Loss: 0.3537934422492981, Accuracy: 0.8502994179725647

# %%
loss_values = fit_model.history['loss']

epochs_range = range(1, len(loss_values) + 1)

plt.plot(epochs_range, loss_values, marker='o', linestyle='-')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.grid(True)
plt.show()
